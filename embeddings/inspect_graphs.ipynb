# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../'))

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from utils import load_pickle

# %%
base_dir = '../'
data_dir = os.path.join(base_dir, 'data/synthetic')

# %%
# inspect graphs
graph_dir = '/home/anton/Repositories/k-cut-ML/data/synthetic/barabasi_albert_500_32'
g_idx = 0

f_name = os.path.join(data_dir, graph_dir, 'G_{}.pkl'.format(g_idx))
G = load_pickle(f_name)
n = len(G)
m = G.number_of_edges()
density = m / (n * (n-1))
degrees = [G.degree(i) for i in list(G.nodes)]

# %%
len(set(degrees))
#plt.hist(degrees)
# Out:
# 103

# %%
list(map(lambda x: x[1], G.degree))
# Out:
# [71,
#  76,
#  58,
#  107,
#  71,
#  99,
#  86,
#  51,
#  86,
#  89,
#  101,
#  105,
#  71,
#  102,
#  82,
#  104,
#  67,
#  70,
#  70,
#  49,
#  59,
#  112,
#  69,
#  73,
#  111,
#  71,
#  63,
#  87,
#  108,
#  85,
#  69,
#  81,
#  209,
#  194,
#  172,
#  207,
#  184,
#  175,
#  185,
#  158,
#  171,
#  184,
#  159,
#  178,
#  183,
#  180,
#  130,
#  151,
#  156,
#  148,
#  139,
#  159,
#  137,
#  157,
#  155,
#  139,
#  149,
#  120,
#  132,
#  123,
#  139,
#  162,
#  120,
#  120,
#  105,
#  112,
#  102,
#  126,
#  127,
#  117,
#  113,
#  116,
#  122,
#  114,
#  103,
#  104,
#  105,
#  84,
#  103,
#  82,
#  103,
#  92,
#  92,
#  98,
#  101,
#  127,
#  90,
#  91,
#  112,
#  102,
#  91,
#  103,
#  92,
#  82,
#  78,
#  107,
#  114,
#  86,
#  65,
#  90,
#  73,
#  85,
#  97,
#  86,
#  65,
#  86,
#  85,
#  89,
#  87,
#  80,
#  68,
#  85,
#  94,
#  74,
#  90,
#  72,
#  92,
#  71,
#  71,
#  82,
#  65,
#  76,
#  61,
#  85,
#  59,
#  66,
#  59,
#  69,
#  66,
#  79,
#  65,
#  76,
#  68,
#  68,
# ...
